# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrieelz001/projeto-educacao-digital/blob/main/PIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bcrypt
import json
import bcrypt
import statistics
import math

usuarios = {}
nome_arquivo = "cadastro_usuario.json"

def estatisticas():
    dados = [
        {"nome": "ana_silva", "idade": 19, "Gênero": "Mulher", "feedback": 8.5, "N° de acessos": 12, "Tempo Médio (minutos)": 45, "Dias ativos": 10, "Resultado total quiz": 7},
        {"nome": "joão123", "idade": 25, "Gênero": "Homem", "feedback": 8.5, "N° de acessos": 22, "Tempo Médio (minutos)": 67, "Dias ativos": 18, "Resultado total quiz": 6},
        {"nome": "maria_dev", "idade": 31, "Gênero": "Mulher", "feedback": 9.2, "N° de acessos": 35, "Tempo Médio (minutos)": 89, "Dias ativos": 22, "Resultado total quiz": 5},
        {"nome": "lucas09", "idade": 17, "Gênero": "Homem", "feedback": 5.5, "N° de acessos": 8, "Tempo Médio (minutos)": 30, "Dias ativos": 5, "Resultado total quiz": 4},
        {"nome": "gabi2024", "idade": 29, "Gênero": "Mulher", "feedback": 7.0, "N° de acessos": 18, "Tempo Médio (minutos)": 55, "Dias ativos": 14, "Resultado total quiz": 9},
    ]
#LISTA IDADE
    lista_idade = [dado["idade"] for dado in dados]

    media = statistics.mean(lista_idade)
    mediana = statistics.median(lista_idade)
    moda = statistics.mode(lista_idade)
    print("")
    print("Idades: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)

#LISTA FEEDBACK
    lista_feedback = [dado["feedback"] for dado in dados]

    media = statistics.mean(lista_feedback)
    mediana = statistics.median(lista_feedback)
    moda = statistics.mode(lista_feedback)
    print("")
    print("Feedback: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)

#N° DE ACESSOS
    lista_númerodeacessos = [dado["N° de acessos"] for dado in dados]

    media = statistics.mean(lista_númerodeacessos)
    mediana = statistics.median(lista_númerodeacessos)
    moda = statistics.mode(lista_númerodeacessos)
    print("")
    print("N° de acessos: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)

#TEMPO MÉDIO (min)
    lista_tempo_médio = [dado["Tempo Médio (minutos)"] for dado in dados]

    media = statistics.mean(lista_tempo_médio)
    mediana = statistics.median(lista_tempo_médio)
    moda = statistics.mode(lista_tempo_médio)
    print("")
    print("Tempo Médio: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)

#DIAS ATIVOS
    lista_dias_ativos = [dado["Dias ativos"] for dado in dados]

    media = statistics.mean(lista_dias_ativos)
    mediana = statistics.median(lista_dias_ativos)
    moda = statistics.mode(lista_dias_ativos)
    print("")
    print("Dias ativos: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)

#RESULTADO TOTAL DO QUIZ
    lista_resultado_total_quiz = [dado["Resultado total quiz"] for dado in dados]

    media = statistics.mean(lista_resultado_total_quiz)
    mediana = statistics.median(lista_resultado_total_quiz)
    moda = statistics.mode(lista_resultado_total_quiz)
    print("")
    print("Resultado total quiz: ")
    print("Média:", media)
    print("Mediana:", mediana)
    print("Moda:", moda)




def conteudo_logico():
    print("\nPensamento Lógico Computacional\n")
    print("""
Pensamento Lógico Computacional é a habilidade de resolver problemas de forma clara e lógica, como um computador faria.

Você aprenderá os 3 conceitos principais:

1. DECISÃO (condicional):
   Permite que o computador tome decisões com base em condições.

   Exemplo em Python:
   idade = 18
   if idade >= 18:
       print("Você é maior de idade.")
   else:
       print("Você é menor de idade.")

2. REPETIÇÃO (laço de repetição):
   O computador repete uma tarefa várias vezes.

   Exemplo:
   for i in range(3):
       print("Essa é a vez número", i + 1)

3. SEQUÊNCIA:
   O computador executa os comandos na ordem que estão no código.
""")
    input("\nPressione Enter para iniciar o quiz...")
    quiz_logico()

def conteudo_InfraestruturaComputacional():
    print("\nInfraestrutura Computacional\n")
    print("""
Infraestrutura Computacional é o conjunto de recursos físicos e lógicos (hardware e software) que sustentam a operação de sistemas, redes e serviços digitais dentro de uma organização.

Componentes:
- Hardware: servidores, computadores, switches, roteadores, firewalls, dispositivos de armazenamento.
- Software: sistemas operacionais, máquinas virtuais, softwares de backup, monitoramento, firewall e gerenciamento de rede.

Lógica de Funcionamento:
- Toda infraestrutura deve garantir disponibilidade, desempenho, segurança e escalabilidade.
- O tráfego de rede é controlado por roteadores e switches que conectam dispositivos internos e externos.
- Servidores centralizam o processamento e o armazenamento de dados, enquanto os clientes acessam esses recursos.
- Softwares de virtualização permitem rodar vários sistemas em um único servidor físico.
- Políticas de segurança controlam o acesso, monitoram ameaças e realizam backups automáticos.

Tipos de Infraestrutura:
- Local: todos os equipamentos estão fisicamente na empresa.
- Nuvem: recursos são fornecidos por terceiros via internet.
- Híbrida: combinação de local e nuvem.
""")
    input("\nPressione Enter para iniciar o quiz...")
    quiz_infraestrutura()

def conteudo_Ciberseguranca():
    print("\nCibersegurança\n")
    print("""
O que é cibersegurança?
Cibersegurança, abreviação de “tecnologia de segurança cibernética”, refere-se à prática de proteger computadores, servidores, redes e dados contra ataques maliciosos.

Por que a cibersegurança é importante?
- Proteção de informações pessoais
- Segurança empresarial
- Segurança nacional
- Privacidade

Ameaças comuns:
- Malware
- Phishing
- Ransomware
- Engenharia social
- Ataques DDoS

Práticas básicas:
- Use senhas fortes e únicas
- Ative a autenticação de dois fatores (2FA)
- Mantenha o software atualizado
- Cuidado com e-mails de phishing
- Instale software antivírus
- Faça backup dos seus dados
""")
    input("\nPressione Enter para iniciar o quiz...")
    quiz_ciberseguranca()

def quiz_logico():
    perguntas = [
        {"pergunta": "O que a estrutura 'if' faz em Python?", "opcoes": ["a) Repete comandos", "b) Cria listas", "c) Toma decisões", "d) Declara variáveis"], "correta": "c"},
        {"pergunta": "Qual comando é usado para repetir algo 3 vezes?", "opcoes": ["a) if i in range(3)", "b) for i in range(3)", "c) while 3", "d) repeat(3)"], "correta": "b"},
        {"pergunta": "O que é sequência em programação?", "opcoes": ["a) Testar condições", "b) Pular comandos", "c) Executar na ordem", "d) Rodar em paralelo"], "correta": "c"}
    ]
    aplicar_quiz(perguntas)

def quiz_infraestrutura():
    perguntas = [
        {"pergunta": "Qual item faz parte do hardware?", "opcoes": ["a) Firewall físico", "b) Antivírus", "c) Sistema operacional", "d) Software de backup"], "correta": "a"},
        {"pergunta": "O que a infraestrutura deve garantir?", "opcoes": ["a) Apenas velocidade", "b) Somente segurança", "c) Disponibilidade e desempenho", "d) Compartilhamento de tela"], "correta": "c"},
        {"pergunta": "Infraestrutura em nuvem significa:", "opcoes": ["a) Tudo local", "b) Recursos via internet", "c) Servidores pessoais", "d) Equipamento próprio"], "correta": "b"}
    ]
    aplicar_quiz(perguntas)

def quiz_ciberseguranca():
    perguntas = [
        {"pergunta": "O que é Phishing?", "opcoes": ["a) Antivírus", "b) Acesso seguro", "c) Golpe por e-mail", "d) Backup"], "correta": "c"},
        {"pergunta": "Qual dessas é uma boa prática de segurança?", "opcoes": ["a) Repetir senhas", "b) Ignorar atualizações", "c) Usar 2FA", "d) Desativar antivírus"], "correta": "c"},
        {"pergunta": "Ataques DDoS afetam:", "opcoes": ["a) Impressoras", "b) Banco de dados local", "c) Disponibilidade de rede", "d) Hardware externo"], "correta": "c"}
    ]
    aplicar_quiz(perguntas)

def aplicar_quiz(perguntas):
    acertos = 0
    for q in perguntas:
        print("\n" + q["pergunta"])
        for op in q["opcoes"]:
            print(op)
        resposta = input("Sua resposta: ").lower()
        if resposta == q["correta"]:
            print("Correto!")
            acertos += 1
        else:
            print(f"Errado. Resposta correta: {q['correta']}")
    print(f"\nVocê acertou {acertos} de {len(perguntas)} perguntas.\n")

# MENU PRINCIPAL
while True:
    print(" MENU ".center(30, "="))
    print("1 - Cadastrar")
    print("2 - Login")
    print("3 - Estatísticas")
    print("4 - Encerrar")
    print("=" * 30)

    opcao = input("Escolha uma opção: ")

    if opcao == "1":
        username = input("Digite um nome de usuário: ")
        idade = int(input("Digite a sua idade: "))
        genero = input("Qual o seu gênero (Mulher/Homem): ").lower()
        senha = input("Digite uma senha: ")
        senha_criptografada = bcrypt.hashpw(senha.encode(), bcrypt.gensalt())

        usuarios[username] = {
            "senha": senha_criptografada.decode("utf-8"),
            "idade": idade,
            "genero": genero
        }

        with open(nome_arquivo, "w") as f:
            json.dump(usuarios, f, indent=4)
        print("Usuário cadastrado com sucesso!\n")

    elif opcao == "2":
        username_login = input("Digite seu nome de usuário: ")
        senha_login = input("Digite sua senha: ")

        try:
            with open(nome_arquivo, "r") as f:
                usuarios = json.load(f)

            if username_login in usuarios:
                senha_salva = usuarios[username_login]["senha"].encode()
                if bcrypt.checkpw(senha_login.encode(), senha_salva):
                    print("Login realizado com sucesso!\n")

                    while True:
                        print(" CONTEÚDO ".center(30, "="))
                        print("1 - Pensamento Lógico Computacional")
                        print("2 - Infraestrutura Computacional")
                        print("3 - Cibersegurança")
                        print("4 - Sair do conteúdo")
                        print("=" * 30)

                        escolha = input("Escolha uma disciplina: ")

                        if escolha == "1":
                            conteudo_logico()
                        elif escolha == "2":
                            conteudo_InfraestruturaComputacional()
                        elif escolha == "3":
                            conteudo_Ciberseguranca()
                        elif escolha == "4":
                            print("Saindo do conteúdo...\n")
                            break
                        else:
                            print("Opção inválida.\n")
                else:
                    print("Senha incorreta!\n")
            else:
                print("Usuário não encontrado!\n")
        except FileNotFoundError:
            print("Arquivo de usuários não encontrado. Cadastre-se primeiro.\n")

    elif opcao == "3":
        estatisticas()

    elif opcao == "4":
        print("Saindo do programa...")
        break

    else:
        print("Opção inválida. Tente novamente.\n")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 4.8 MB/s eta 0:00:00
# ...
# ============ MENU ============
# 1 - Cadastrar
# 2 - Login
# 3 - Estatísticas
# 4 - Encerrar
# ...
# Escolha uma opção: 3
#
# Idades:
# Média: 24.2
# Mediana: 25
# Moda: 19
#
# Feedback:
# Média: 7.74
# Mediana: 8.5
# Moda: 8.5
#
# N° de acessos:
# Média: 19
# Mediana: 18
# Moda: 12
#
# Tempo Médio:
# Média: 57.2
# Mediana: 55
# Moda: 45
#
# Dias ativos:
# Média: 13.8
# Mediana: 14
# Moda: 10
#
# Resultado total quiz:
# Média: 6.2
# Mediana: 6
# Moda: 7
# ============ MENU ============
# 1 - Cadastrar
# 2 - Login
# 3 - Estatísticas
# 4 - Encerrar
# ...
